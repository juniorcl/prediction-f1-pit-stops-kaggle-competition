# %% [markdown]
# # Imports

# %%
import re
import torch
import optuna
import pickle

import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn import set_config
from category_encoders import CatBoostEncoder

from sklearn.metrics import roc_auc_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import TargetEncoder, StandardScaler, RobustScaler, LabelEncoder
from sklearn.model_selection import cross_val_score, StratifiedKFold

from tensorflow.keras import layers
from tensorflow.keras import callbacks
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Utils

# %%
set_config(transform_output="pandas")

# %%
def dump_pickle(file_obj, file_path):
    with open(file_path, 'bw') as file:
        pickle.dump(file_obj, file)

# %%
column_transformer = ColumnTransformer([
    (
        'target_encoder', 
        TargetEncoder(), 
        ['driver', 'compound', 'race']
    ),
    (
        'catboost_encoder', 
        CatBoostEncoder(), 
        ['driver', 'compound', 'race']
    ),
    (
        'standard_scaler', 
        StandardScaler(), 
        ['lapnumber', 'position', 'raceprogress', 'year', 'position_norm', 'race_progress_sin', 'position_vs_mean']
    ),
    (
        'robust_scaler', 
        RobustScaler(), 
        [
            'position_change', 'cumulative_degradation', 'laptime_delta', 'laptime_s', 'stint', 'driver_mean_lap', 'tyrelife', 'delta_x_tyre_life', 
            'compound_tyre_life', 'stint_progress', 'tyre_life_ratio', 'degradation_per_lap', 'position_change_cum', 'laps_since_pit', 'lap_time_inv',  
            'lap_time_vs_race_mean', 'lap_time_x_tyre', 'position_x_progress', 'degradation_x_progress', 'race_progress_squared', 'driver_avg_position' 
        ]
    ),
], remainder="passthrough")

# %% [markdown]
# # Loading Dataset

# %%
X_train = pd.read_parquet('../data/X_train.parquet')
y_train = pd.read_parquet('../data/y_train.parquet')

# %%
X_train.head()
# Out:
#    driver compound                   race  year  pitstop  lapnumber  stint  \
# id
# 0    D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1    D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2     ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3     SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4    D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#     tyrelife  position  laptime_s  ...  treeraceprogress  treeposition  \
# id                                 ...
# 0       39.0         8     78.491  ...          0.298107      0.207392
# 1        7.0         4     75.095  ...          0.298107      0.185508
# 2       22.0        13     70.945  ...          0.298107      0.207392
# 3        2.0         7     94.361  ...          0.102471      0.185508
# 4        6.0         2    107.878  ...          0.298107      0.185508
#
#     treelaptime_s  treecumulative_degradation  treeraceprogress_position  \
# id
# 0        0.252153                    0.279021                   0.298107
# 1        0.252153                    0.586119                   0.298107
# 2        0.252153                    0.207676                   0.298107
# 3        0.178575                    0.138352                   0.102471
# 4        0.178575                    0.138352                   0.298107
#
#     treeraceprogress_laptime_s  treeraceprogress_cumulative_degradation  \
# id
# 0                     0.298107                                 0.321361
# 1                     0.298107                                 0.610176
# 2                     0.298107                                 0.423519
# 3                     0.102471                                 0.043550
# 4                     0.298107                                 0.206543
#
#     treeposition_laptime_s  treeposition_cumulative_degradation  \
# id
# 0                 0.252153                             0.279021
# 1                 0.252153                             0.544023
# 2                 0.252153                             0.228194
# 3                 0.178575                             0.138352
# 4                 0.178575                             0.138352
#
#     treelaptime_s_cumulative_degradation
# id
# 0                               0.253721
# 1                               0.613159
# 2                               0.231339
# 3                               0.070991
# 4                               0.153276
#
# [5 rows x 72 columns]

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Cross Validation

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

aucs = []

for fold, (train_idx, valid_idx) in enumerate(cv.split(X_train, y_train)):

    print(f"\n======== Fold {fold + 1} ========")

    X_tr = X_train.iloc[train_idx, :]
    X_val = X_train.iloc[valid_idx, :]

    y_tr = y_train.iloc[train_idx, 0]
    y_val = y_train.iloc[valid_idx, 0]

    X_tr_transformed = column_transformer.fit_transform(X_tr, y_tr)
    X_val_transformed = column_transformer.transform(X_val)

    X_tr_transformed = np.asarray(X_tr_transformed).astype(np.float32)
    X_val_transformed = np.asarray(X_val_transformed).astype(np.float32)

    y_tr = y_tr.values.astype(np.float32)
    y_val = y_val.values.astype(np.float32)

    input_dim = X_tr_transformed.shape[1]

    model = Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(512, activation="swish", kernel_regularizer=regularizers.l2(1e-4)),
        layers.BatchNormalization(),
        layers.Dropout(0.30),

        layers.Dense(256, activation="swish", kernel_regularizer=regularizers.l2(1e-4)),
        layers.BatchNormalization(),
        layers.Dropout(0.25),

        layers.Dense(128, activation="swish", kernel_regularizer=regularizers.l2(1e-4)),
        layers.BatchNormalization(),
        layers.Dropout(0.20),

        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    early_stopping = callbacks.EarlyStopping(
        monitor="val_auc",
        mode="max",
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor="val_auc",
        mode="max",
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )

    checkpoint = callbacks.ModelCheckpoint(
        filepath=f"models/nn_fold_{fold + 1}.keras",
        monitor="val_auc",
        mode="max",
        save_best_only=True,
        save_weights_only=False,
        verbose=1
    )

    history = model.fit(
        X_tr_transformed,
        y_tr,
        validation_data=(X_val_transformed, y_val),
        epochs=200,
        batch_size=1024,
        callbacks=[early_stopping, reduce_lr, checkpoint],
        verbose=1
    )

    val_preds = model.predict(X_val_transformed, verbose=0).ravel()

    oof_preds[valid_idx] = val_preds

    auc = roc_auc_score(y_val, val_preds)
    aucs.append(auc)

    print(f"Fold AUC: {auc:.6f}")


print("\n==============================")
print(f"CV AUC: {np.mean(aucs):.6f}")
print(f"STD: {np.std(aucs):.6f}")
print("==============================")
# Out:
# ======== Fold 1 ========
# Epoch 1/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8232 - loss: 0.5337
# Epoch 1: val_auc improved from None to 0.90836, saving model to models/nn_fold_1.keras
#
# Epoch 1: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - auc: 0.8627 - loss: 0.4357 - val_auc: 0.9084 - val_loss: 0.3737 - learning_rate: 0.0010
# Epoch 2/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9094 - loss: 0.3472
# Epoch 2: val_auc improved from 0.90836 to 0.92089, saving model to models/nn_fold_1.keras
#
# Epoch 2: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9131 - loss: 0.3383 - val_auc: 0.9209 - val_loss: 0.3269 - learning_rate: 0.0010
# Epoch 3/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9194 - loss: 0.3213
# Epoch 3: val_auc improved from 0.92089 to 0.92885, saving model to models/nn_fold_1.keras
#
# Epoch 3: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9205 - loss: 0.3164 - val_auc: 0.9289 - val_loss: 0.3048 - learning_rate: 0.0010
# Epoch 4/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9226 - loss: 0.3062
# Epoch 4: val_auc improved from 0.92885 to 0.92942, saving model to models/nn_fold_1.keras
#
# Epoch 4: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9236 - loss: 0.3028 - val_auc: 0.9294 - val_loss: 0.2922 - learning_rate: 0.0010
# Epoch 5/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9256 - loss: 0.2948
# Epoch 5: val_auc improved from 0.92942 to 0.93121, saving model to models/nn_fold_1.keras
#
# Epoch 5: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9257 - loss: 0.2934 - val_auc: 0.9312 - val_loss: 0.2883 - learning_rate: 0.0010
# Epoch 6/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9266 - loss: 0.2889
# Epoch 6: val_auc improved from 0.93121 to 0.93122, saving model to models/nn_fold_1.keras
#
# Epoch 6: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9269 - loss: 0.2878 - val_auc: 0.9312 - val_loss: 0.2833 - learning_rate: 0.0010
# Epoch 7/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9277 - loss: 0.2838
# Epoch 7: val_auc improved from 0.93122 to 0.93202, saving model to models/nn_fold_1.keras
#
# Epoch 7: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9279 - loss: 0.2829 - val_auc: 0.9320 - val_loss: 0.2779 - learning_rate: 0.0010
# Epoch 8/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9284 - loss: 0.2806
# Epoch 8: val_auc improved from 0.93202 to 0.93260, saving model to models/nn_fold_1.keras
#
# Epoch 8: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9284 - loss: 0.2800 - val_auc: 0.9326 - val_loss: 0.2758 - learning_rate: 0.0010
# Epoch 9/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9281 - loss: 0.2798
# Epoch 9: val_auc improved from 0.93260 to 0.93453, saving model to models/nn_fold_1.keras
#
# Epoch 9: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9292 - loss: 0.2774 - val_auc: 0.9345 - val_loss: 0.2738 - learning_rate: 0.0010
# Epoch 10/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9289 - loss: 0.2773
# Epoch 10: val_auc did not improve from 0.93453
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9298 - loss: 0.2757 - val_auc: 0.9327 - val_loss: 0.2726 - learning_rate: 0.0010
# Epoch 11/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9300 - loss: 0.2749
# Epoch 11: val_auc did not improve from 0.93453
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9303 - loss: 0.2742 - val_auc: 0.9329 - val_loss: 0.2747 - learning_rate: 0.0010
# Epoch 12/200
# 340/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9298 - loss: 0.2750
# Epoch 12: val_auc did not improve from 0.93453
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9306 - loss: 0.2735 - val_auc: 0.9341 - val_loss: 0.2709 - learning_rate: 0.0010
# Epoch 13/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9306 - loss: 0.2738
# Epoch 13: val_auc did not improve from 0.93453
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9310 - loss: 0.2729 - val_auc: 0.9341 - val_loss: 0.2732 - learning_rate: 0.0010
# Epoch 14/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9314 - loss: 0.2718
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 14: val_auc did not improve from 0.93453
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9315 - loss: 0.2715 - val_auc: 0.9332 - val_loss: 0.2778 - learning_rate: 0.0010
# Epoch 15/200
# 340/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9336 - loss: 0.2682
# Epoch 15: val_auc improved from 0.93453 to 0.93467, saving model to models/nn_fold_1.keras
#
# Epoch 15: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9335 - loss: 0.2676 - val_auc: 0.9347 - val_loss: 0.2728 - learning_rate: 5.0000e-04
# Epoch 16/200
# 340/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9339 - loss: 0.2665
# Epoch 16: val_auc improved from 0.93467 to 0.93578, saving model to models/nn_fold_1.keras
#
# Epoch 16: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9339 - loss: 0.2661 - val_auc: 0.9358 - val_loss: 0.2660 - learning_rate: 5.0000e-04
# Epoch 17/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9337 - loss: 0.2658
# Epoch 17: val_auc improved from 0.93578 to 0.93619, saving model to models/nn_fold_1.keras
#
# Epoch 17: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9341 - loss: 0.2651 - val_auc: 0.9362 - val_loss: 0.2627 - learning_rate: 5.0000e-04
# Epoch 18/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9350 - loss: 0.2635
# Epoch 18: val_auc did not improve from 0.93619
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9342 - loss: 0.2650 - val_auc: 0.9360 - val_loss: 0.2637 - learning_rate: 5.0000e-04
# Epoch 19/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9350 - loss: 0.2631
# Epoch 19: val_auc improved from 0.93619 to 0.93715, saving model to models/nn_fold_1.keras
#
# Epoch 19: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9344 - loss: 0.2645 - val_auc: 0.9372 - val_loss: 0.2615 - learning_rate: 5.0000e-04
# Epoch 20/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9352 - loss: 0.2629
# Epoch 20: val_auc did not improve from 0.93715
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9348 - loss: 0.2636 - val_auc: 0.9364 - val_loss: 0.2637 - learning_rate: 5.0000e-04
# Epoch 21/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9357 - loss: 0.2620
# Epoch 21: val_auc did not improve from 0.93715
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9351 - loss: 0.2630 - val_auc: 0.9365 - val_loss: 0.2616 - learning_rate: 5.0000e-04
# Epoch 22/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9355 - loss: 0.2616
# Epoch 22: val_auc did not improve from 0.93715
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9352 - loss: 0.2626 - val_auc: 0.9367 - val_loss: 0.2611 - learning_rate: 5.0000e-04
# Epoch 23/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9361 - loss: 0.2613
# Epoch 23: val_auc improved from 0.93715 to 0.93725, saving model to models/nn_fold_1.keras
#
# Epoch 23: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9354 - loss: 0.2624 - val_auc: 0.9372 - val_loss: 0.2622 - learning_rate: 5.0000e-04
# Epoch 24/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9351 - loss: 0.2626
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 24: val_auc did not improve from 0.93725
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9356 - loss: 0.2618 - val_auc: 0.9360 - val_loss: 0.2624 - learning_rate: 5.0000e-04
# Epoch 25/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9368 - loss: 0.2602
# Epoch 25: val_auc improved from 0.93725 to 0.93902, saving model to models/nn_fold_1.keras
#
# Epoch 25: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9370 - loss: 0.2591 - val_auc: 0.9390 - val_loss: 0.2565 - learning_rate: 2.5000e-04
# Epoch 26/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9372 - loss: 0.2584
# Epoch 26: val_auc improved from 0.93902 to 0.93928, saving model to models/nn_fold_1.keras
#
# Epoch 26: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9375 - loss: 0.2579 - val_auc: 0.9393 - val_loss: 0.2558 - learning_rate: 2.5000e-04
# Epoch 27/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9376 - loss: 0.2570
# Epoch 27: val_auc did not improve from 0.93928
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9375 - loss: 0.2577 - val_auc: 0.9382 - val_loss: 0.2577 - learning_rate: 2.5000e-04
# Epoch 28/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9385 - loss: 0.2558
# Epoch 28: val_auc did not improve from 0.93928
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9378 - loss: 0.2572 - val_auc: 0.9389 - val_loss: 0.2563 - learning_rate: 2.5000e-04
# Epoch 29/200
# 340/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9383 - loss: 0.2559
# Epoch 29: val_auc improved from 0.93928 to 0.93974, saving model to models/nn_fold_1.keras
#
# Epoch 29: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9380 - loss: 0.2565 - val_auc: 0.9397 - val_loss: 0.2544 - learning_rate: 2.5000e-04
# Epoch 30/200
# 340/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9383 - loss: 0.2561
# Epoch 30: val_auc did not improve from 0.93974
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9380 - loss: 0.2565 - val_auc: 0.9397 - val_loss: 0.2544 - learning_rate: 2.5000e-04
# Epoch 31/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9388 - loss: 0.2547
# Epoch 31: val_auc did not improve from 0.93974
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9382 - loss: 0.2560 - val_auc: 0.9390 - val_loss: 0.2565 - learning_rate: 2.5000e-04
# Epoch 32/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9376 - loss: 0.2569
# Epoch 32: val_auc did not improve from 0.93974
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9383 - loss: 0.2557 - val_auc: 0.9396 - val_loss: 0.2550 - learning_rate: 2.5000e-04
# Epoch 33/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9384 - loss: 0.2552
# Epoch 33: val_auc improved from 0.93974 to 0.94005, saving model to models/nn_fold_1.keras
#
# Epoch 33: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9385 - loss: 0.2553 - val_auc: 0.9401 - val_loss: 0.2541 - learning_rate: 2.5000e-04
# Epoch 34/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9388 - loss: 0.2545
# Epoch 34: val_auc improved from 0.94005 to 0.94039, saving model to models/nn_fold_1.keras
#
# Epoch 34: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9386 - loss: 0.2550 - val_auc: 0.9404 - val_loss: 0.2535 - learning_rate: 2.5000e-04
# Epoch 35/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9389 - loss: 0.2547
# Epoch 35: val_auc did not improve from 0.94039
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9384 - loss: 0.2553 - val_auc: 0.9398 - val_loss: 0.2533 - learning_rate: 2.5000e-04
# Epoch 36/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9382 - loss: 0.2564
# Epoch 36: val_auc did not improve from 0.94039
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9387 - loss: 0.2548 - val_auc: 0.9389 - val_loss: 0.2561 - learning_rate: 2.5000e-04
# Epoch 37/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9385 - loss: 0.2550
# Epoch 37: val_auc improved from 0.94039 to 0.94046, saving model to models/nn_fold_1.keras
#
# Epoch 37: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9385 - loss: 0.2551 - val_auc: 0.9405 - val_loss: 0.2523 - learning_rate: 2.5000e-04
# Epoch 38/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9391 - loss: 0.2537
# Epoch 38: val_auc did not improve from 0.94046
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9388 - loss: 0.2545 - val_auc: 0.9404 - val_loss: 0.2528 - learning_rate: 2.5000e-04
# Epoch 39/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9395 - loss: 0.2538
# Epoch 39: val_auc improved from 0.94046 to 0.94056, saving model to models/nn_fold_1.keras
#
# Epoch 39: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9388 - loss: 0.2545 - val_auc: 0.9406 - val_loss: 0.2526 - learning_rate: 2.5000e-04
# Epoch 40/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9392 - loss: 0.2538
# Epoch 40: val_auc improved from 0.94056 to 0.94075, saving model to models/nn_fold_1.keras
#
# Epoch 40: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9392 - loss: 0.2538 - val_auc: 0.9408 - val_loss: 0.2521 - learning_rate: 2.5000e-04
# Epoch 41/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9382 - loss: 0.2557
# Epoch 41: val_auc improved from 0.94075 to 0.94084, saving model to models/nn_fold_1.keras
#
# Epoch 41: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9391 - loss: 0.2538 - val_auc: 0.9408 - val_loss: 0.2513 - learning_rate: 2.5000e-04
# Epoch 42/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9393 - loss: 0.2534
# Epoch 42: val_auc did not improve from 0.94084
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9391 - loss: 0.2539 - val_auc: 0.9399 - val_loss: 0.2531 - learning_rate: 2.5000e-04
# Epoch 43/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9395 - loss: 0.2536
# Epoch 43: val_auc improved from 0.94084 to 0.94096, saving model to models/nn_fold_1.keras
#
# Epoch 43: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9394 - loss: 0.2533 - val_auc: 0.9410 - val_loss: 0.2515 - learning_rate: 2.5000e-04
# Epoch 44/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9397 - loss: 0.2526
# Epoch 44: val_auc did not improve from 0.94096
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9394 - loss: 0.2534 - val_auc: 0.9405 - val_loss: 0.2526 - learning_rate: 2.5000e-04
# Epoch 45/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9394 - loss: 0.2532
# Epoch 45: val_auc did not improve from 0.94096
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9393 - loss: 0.2538 - val_auc: 0.9406 - val_loss: 0.2525 - learning_rate: 2.5000e-04
# Epoch 46/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9389 - loss: 0.2540
# Epoch 46: val_auc did not improve from 0.94096
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9398 - loss: 0.2526 - val_auc: 0.9406 - val_loss: 0.2531 - learning_rate: 2.5000e-04
# Epoch 47/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9395 - loss: 0.2530
# Epoch 47: val_auc did not improve from 0.94096
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9395 - loss: 0.2532 - val_auc: 0.9398 - val_loss: 0.2546 - learning_rate: 2.5000e-04
# Epoch 48/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9401 - loss: 0.2516
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 48: val_auc did not improve from 0.94096
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9399 - loss: 0.2525 - val_auc: 0.9409 - val_loss: 0.2517 - learning_rate: 2.5000e-04
# Epoch 49/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9412 - loss: 0.2501
# Epoch 49: val_auc improved from 0.94096 to 0.94184, saving model to models/nn_fold_1.keras
#
# Epoch 49: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9409 - loss: 0.2507 - val_auc: 0.9418 - val_loss: 0.2496 - learning_rate: 1.2500e-04
# Epoch 50/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9406 - loss: 0.2507
# Epoch 50: val_auc did not improve from 0.94184
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9409 - loss: 0.2506 - val_auc: 0.9415 - val_loss: 0.2499 - learning_rate: 1.2500e-04
# Epoch 51/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9416 - loss: 0.2493
# Epoch 51: val_auc did not improve from 0.94184
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9412 - loss: 0.2500 - val_auc: 0.9415 - val_loss: 0.2495 - learning_rate: 1.2500e-04
# Epoch 52/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9413 - loss: 0.2502
# Epoch 52: val_auc did not improve from 0.94184
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9412 - loss: 0.2498 - val_auc: 0.9418 - val_loss: 0.2490 - learning_rate: 1.2500e-04
# Epoch 53/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9407 - loss: 0.2503
# Epoch 53: val_auc improved from 0.94184 to 0.94273, saving model to models/nn_fold_1.keras
#
# Epoch 53: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9414 - loss: 0.2494 - val_auc: 0.9427 - val_loss: 0.2474 - learning_rate: 1.2500e-04
# Epoch 54/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9414 - loss: 0.2496
# Epoch 54: val_auc improved from 0.94273 to 0.94280, saving model to models/nn_fold_1.keras
#
# Epoch 54: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9415 - loss: 0.2492 - val_auc: 0.9428 - val_loss: 0.2470 - learning_rate: 1.2500e-04
# Epoch 55/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9411 - loss: 0.2496
# Epoch 55: val_auc improved from 0.94280 to 0.94289, saving model to models/nn_fold_1.keras
#
# Epoch 55: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9414 - loss: 0.2493 - val_auc: 0.9429 - val_loss: 0.2467 - learning_rate: 1.2500e-04
# Epoch 56/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9413 - loss: 0.2496
# Epoch 56: val_auc did not improve from 0.94289
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9415 - loss: 0.2490 - val_auc: 0.9428 - val_loss: 0.2472 - learning_rate: 1.2500e-04
# Epoch 57/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9413 - loss: 0.2492
# Epoch 57: val_auc did not improve from 0.94289
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9415 - loss: 0.2490 - val_auc: 0.9423 - val_loss: 0.2481 - learning_rate: 1.2500e-04
# Epoch 58/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9425 - loss: 0.2468
# Epoch 58: val_auc did not improve from 0.94289
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9419 - loss: 0.2483 - val_auc: 0.9428 - val_loss: 0.2471 - learning_rate: 1.2500e-04
# Epoch 59/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9417 - loss: 0.2489
# Epoch 59: val_auc improved from 0.94289 to 0.94309, saving model to models/nn_fold_1.keras
#
# Epoch 59: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9417 - loss: 0.2488 - val_auc: 0.9431 - val_loss: 0.2462 - learning_rate: 1.2500e-04
# Epoch 60/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9418 - loss: 0.2481
# Epoch 60: val_auc improved from 0.94309 to 0.94326, saving model to models/nn_fold_1.keras
#
# Epoch 60: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9417 - loss: 0.2486 - val_auc: 0.9433 - val_loss: 0.2457 - learning_rate: 1.2500e-04
# Epoch 61/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9422 - loss: 0.2474
# Epoch 61: val_auc did not improve from 0.94326
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9419 - loss: 0.2480 - val_auc: 0.9425 - val_loss: 0.2472 - learning_rate: 1.2500e-04
# Epoch 62/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9423 - loss: 0.2465
# Epoch 62: val_auc did not improve from 0.94326
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9420 - loss: 0.2479 - val_auc: 0.9430 - val_loss: 0.2460 - learning_rate: 1.2500e-04
# Epoch 63/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9427 - loss: 0.2468
# Epoch 63: val_auc did not improve from 0.94326
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9421 - loss: 0.2475 - val_auc: 0.9431 - val_loss: 0.2460 - learning_rate: 1.2500e-04
# Epoch 64/200
# 339/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9428 - loss: 0.2463
# Epoch 64: val_auc did not improve from 0.94326
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9421 - loss: 0.2478 - val_auc: 0.9432 - val_loss: 0.2457 - learning_rate: 1.2500e-04
# Epoch 65/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9418 - loss: 0.2477
# Epoch 65: val_auc improved from 0.94326 to 0.94366, saving model to models/nn_fold_1.keras
#
# Epoch 65: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9419 - loss: 0.2480 - val_auc: 0.9437 - val_loss: 0.2452 - learning_rate: 1.2500e-04
# Epoch 66/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9426 - loss: 0.2464
# Epoch 66: val_auc did not improve from 0.94366
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9422 - loss: 0.2475 - val_auc: 0.9435 - val_loss: 0.2457 - learning_rate: 1.2500e-04
# Epoch 67/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9422 - loss: 0.2482
# Epoch 67: val_auc did not improve from 0.94366
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9423 - loss: 0.2474 - val_auc: 0.9431 - val_loss: 0.2460 - learning_rate: 1.2500e-04
# Epoch 68/200
# 340/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9423 - loss: 0.2473
# Epoch 68: val_auc did not improve from 0.94366
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9421 - loss: 0.2476 - val_auc: 0.9433 - val_loss: 0.2457 - learning_rate: 1.2500e-04
# Epoch 69/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9428 - loss: 0.2464
# Epoch 69: val_auc did not improve from 0.94366
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9422 - loss: 0.2474 - val_auc: 0.9430 - val_loss: 0.2463 - learning_rate: 1.2500e-04
# Epoch 70/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9418 - loss: 0.2482
# Epoch 70: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 70: val_auc did not improve from 0.94366
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - auc: 0.9423 - loss: 0.2472 - val_auc: 0.9429 - val_loss: 0.2462 - learning_rate: 1.2500e-04
# Epoch 71/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9429 - loss: 0.2461
# Epoch 71: val_auc did not improve from 0.94366
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - auc: 0.9429 - loss: 0.2459 - val_auc: 0.9433 - val_loss: 0.2453 - learning_rate: 6.2500e-05
# Epoch 72/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9437 - loss: 0.2448
# Epoch 72: val_auc did not improve from 0.94366
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - auc: 0.9433 - loss: 0.2454 - val_auc: 0.9435 - val_loss: 0.2450 - learning_rate: 6.2500e-05
# Epoch 73/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9427 - loss: 0.2469
# Epoch 73: val_auc improved from 0.94366 to 0.94404, saving model to models/nn_fold_1.keras
#
# Epoch 73: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - auc: 0.9432 - loss: 0.2456 - val_auc: 0.9440 - val_loss: 0.2439 - learning_rate: 6.2500e-05
# Epoch 74/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9435 - loss: 0.2452
# Epoch 74: val_auc did not improve from 0.94404
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9432 - loss: 0.2455 - val_auc: 0.9439 - val_loss: 0.2443 - learning_rate: 6.2500e-05
# Epoch 75/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9435 - loss: 0.2448
# Epoch 75: val_auc did not improve from 0.94404
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9432 - loss: 0.2453 - val_auc: 0.9437 - val_loss: 0.2446 - learning_rate: 6.2500e-05
# Epoch 76/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9433 - loss: 0.2455
# Epoch 76: val_auc did not improve from 0.94404
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - auc: 0.9432 - loss: 0.2452 - val_auc: 0.9437 - val_loss: 0.2447 - learning_rate: 6.2500e-05
# Epoch 77/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9437 - loss: 0.2446
# Epoch 77: val_auc improved from 0.94404 to 0.94429, saving model to models/nn_fold_1.keras
#
# Epoch 77: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - auc: 0.9435 - loss: 0.2447 - val_auc: 0.9443 - val_loss: 0.2436 - learning_rate: 6.2500e-05
# Epoch 78/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9432 - loss: 0.2453
# Epoch 78: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - auc: 0.9435 - loss: 0.2448 - val_auc: 0.9441 - val_loss: 0.2439 - learning_rate: 6.2500e-05
# Epoch 79/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9431 - loss: 0.2450
# Epoch 79: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - auc: 0.9436 - loss: 0.2445 - val_auc: 0.9439 - val_loss: 0.2446 - learning_rate: 6.2500e-05
# Epoch 80/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9431 - loss: 0.2448
# Epoch 80: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9434 - loss: 0.2449 - val_auc: 0.9440 - val_loss: 0.2440 - learning_rate: 6.2500e-05
# Epoch 81/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9439 - loss: 0.2441
# Epoch 81: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - auc: 0.9437 - loss: 0.2443 - val_auc: 0.9440 - val_loss: 0.2439 - learning_rate: 6.2500e-05
# Epoch 82/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9431 - loss: 0.2461
# Epoch 82: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 82: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - auc: 0.9436 - loss: 0.2445 - val_auc: 0.9436 - val_loss: 0.2447 - learning_rate: 6.2500e-05
# Epoch 83/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9437 - loss: 0.2442
# Epoch 83: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - auc: 0.9438 - loss: 0.2440 - val_auc: 0.9440 - val_loss: 0.2438 - learning_rate: 3.1250e-05
# Epoch 84/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9440 - loss: 0.2437
# Epoch 84: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - auc: 0.9440 - loss: 0.2436 - val_auc: 0.9441 - val_loss: 0.2438 - learning_rate: 3.1250e-05
# Epoch 85/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9439 - loss: 0.2441
# Epoch 85: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - auc: 0.9441 - loss: 0.2435 - val_auc: 0.9437 - val_loss: 0.2443 - learning_rate: 3.1250e-05
# Epoch 86/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9437 - loss: 0.2441
# Epoch 86: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - auc: 0.9441 - loss: 0.2435 - val_auc: 0.9441 - val_loss: 0.2436 - learning_rate: 3.1250e-05
# Epoch 87/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9440 - loss: 0.2439
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 87: val_auc did not improve from 0.94429
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - auc: 0.9443 - loss: 0.2431 - val_auc: 0.9442 - val_loss: 0.2435 - learning_rate: 3.1250e-05
# Epoch 88/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9437 - loss: 0.2441
# Epoch 88: val_auc improved from 0.94429 to 0.94458, saving model to models/nn_fold_1.keras
#
# Epoch 88: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9442 - loss: 0.2432 - val_auc: 0.9446 - val_loss: 0.2427 - learning_rate: 1.5625e-05
# Epoch 89/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9449 - loss: 0.2413
# Epoch 89: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - auc: 0.9443 - loss: 0.2430 - val_auc: 0.9442 - val_loss: 0.2434 - learning_rate: 1.5625e-05
# Epoch 90/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9445 - loss: 0.2429
# Epoch 90: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - auc: 0.9444 - loss: 0.2429 - val_auc: 0.9442 - val_loss: 0.2433 - learning_rate: 1.5625e-05
# Epoch 91/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - auc: 0.9444 - loss: 0.2433
# Epoch 91: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - auc: 0.9444 - loss: 0.2428 - val_auc: 0.9444 - val_loss: 0.2430 - learning_rate: 1.5625e-05
# Epoch 92/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9442 - loss: 0.2427
# Epoch 92: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - auc: 0.9443 - loss: 0.2430 - val_auc: 0.9442 - val_loss: 0.2434 - learning_rate: 1.5625e-05
# Epoch 93/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9440 - loss: 0.2435
# Epoch 93: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 93: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - auc: 0.9441 - loss: 0.2434 - val_auc: 0.9445 - val_loss: 0.2428 - learning_rate: 1.5625e-05
# Epoch 94/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9448 - loss: 0.2420
# Epoch 94: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9445 - loss: 0.2425 - val_auc: 0.9445 - val_loss: 0.2429 - learning_rate: 7.8125e-06
# Epoch 95/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9447 - loss: 0.2422
# Epoch 95: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - auc: 0.9445 - loss: 0.2425 - val_auc: 0.9445 - val_loss: 0.2429 - learning_rate: 7.8125e-06
# Epoch 96/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9449 - loss: 0.2416
# Epoch 96: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - auc: 0.9445 - loss: 0.2426 - val_auc: 0.9442 - val_loss: 0.2434 - learning_rate: 7.8125e-06
# Epoch 97/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9449 - loss: 0.2423
# Epoch 97: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9444 - loss: 0.2427 - val_auc: 0.9443 - val_loss: 0.2431 - learning_rate: 7.8125e-06
# Epoch 98/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9447 - loss: 0.2428
# Epoch 98: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 98: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9442 - loss: 0.2430 - val_auc: 0.9442 - val_loss: 0.2433 - learning_rate: 7.8125e-06
# Epoch 99/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9443 - loss: 0.2427
# Epoch 99: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - auc: 0.9444 - loss: 0.2426 - val_auc: 0.9445 - val_loss: 0.2428 - learning_rate: 3.9063e-06
# Epoch 100/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9446 - loss: 0.2426
# Epoch 100: val_auc did not improve from 0.94458
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - auc: 0.9447 - loss: 0.2422 - val_auc: 0.9445 - val_loss: 0.2427 - learning_rate: 3.9063e-06
# Epoch 101/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9440 - loss: 0.2434
# Epoch 101: val_auc improved from 0.94458 to 0.94467, saving model to models/nn_fold_1.keras
#
# Epoch 101: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - auc: 0.9444 - loss: 0.2427 - val_auc: 0.9447 - val_loss: 0.2426 - learning_rate: 3.9063e-06
# Epoch 102/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9448 - loss: 0.2425
# Epoch 102: val_auc did not improve from 0.94467
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - auc: 0.9445 - loss: 0.2425 - val_auc: 0.9445 - val_loss: 0.2428 - learning_rate: 3.9063e-06
# Epoch 103/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9437 - loss: 0.2442
# Epoch 103: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 103: val_auc did not improve from 0.94467
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9446 - loss: 0.2423 - val_auc: 0.9447 - val_loss: 0.2426 - learning_rate: 3.9063e-06
# Epoch 104/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9451 - loss: 0.2412
# Epoch 104: val_auc did not improve from 0.94467
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - auc: 0.9444 - loss: 0.2426 - val_auc: 0.9446 - val_loss: 0.2426 - learning_rate: 1.9531e-06
# Epoch 105/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9448 - loss: 0.2415
# Epoch 105: val_auc did not improve from 0.94467
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - auc: 0.9449 - loss: 0.2418 - val_auc: 0.9446 - val_loss: 0.2426 - learning_rate: 1.9531e-06
# Epoch 106/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9443 - loss: 0.2437
# Epoch 106: val_auc improved from 0.94467 to 0.94482, saving model to models/nn_fold_1.keras
#
# Epoch 106: finished saving model to models/nn_fold_1.keras
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - auc: 0.9446 - loss: 0.2423 - val_auc: 0.9448 - val_loss: 0.2419 - learning_rate: 1.9531e-06
# Epoch 107/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9447 - loss: 0.2419
# Epoch 107: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9447 - loss: 0.2420 - val_auc: 0.9440 - val_loss: 0.2437 - learning_rate: 1.9531e-06
# Epoch 108/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9446 - loss: 0.2426
# Epoch 108: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - auc: 0.9445 - loss: 0.2423 - val_auc: 0.9447 - val_loss: 0.2425 - learning_rate: 1.9531e-06
# Epoch 109/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9443 - loss: 0.2427
# Epoch 109: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - auc: 0.9443 - loss: 0.2428 - val_auc: 0.9447 - val_loss: 0.2425 - learning_rate: 1.9531e-06
# Epoch 110/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9447 - loss: 0.2422
# Epoch 110: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - auc: 0.9447 - loss: 0.2420 - val_auc: 0.9443 - val_loss: 0.2430 - learning_rate: 1.9531e-06
# Epoch 111/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9440 - loss: 0.2438
# Epoch 111: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 111: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9445 - loss: 0.2424 - val_auc: 0.9446 - val_loss: 0.2426 - learning_rate: 1.9531e-06
# Epoch 112/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9446 - loss: 0.2425
# Epoch 112: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9446 - loss: 0.2423 - val_auc: 0.9445 - val_loss: 0.2427 - learning_rate: 1.0000e-06
# Epoch 113/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9451 - loss: 0.2419
# Epoch 113: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - auc: 0.9446 - loss: 0.2423 - val_auc: 0.9446 - val_loss: 0.2425 - learning_rate: 1.0000e-06
# Epoch 114/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9443 - loss: 0.2431
# Epoch 114: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - auc: 0.9445 - loss: 0.2425 - val_auc: 0.9447 - val_loss: 0.2423 - learning_rate: 1.0000e-06
# Epoch 115/200
# 343/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9448 - loss: 0.2419
# Epoch 115: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - auc: 0.9446 - loss: 0.2422 - val_auc: 0.9446 - val_loss: 0.2425 - learning_rate: 1.0000e-06
# Epoch 116/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9448 - loss: 0.2420
# Epoch 116: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - auc: 0.9448 - loss: 0.2421 - val_auc: 0.9441 - val_loss: 0.2434 - learning_rate: 1.0000e-06
# Epoch 117/200
# 341/344 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9446 - loss: 0.2426
# Epoch 117: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - auc: 0.9447 - loss: 0.2420 - val_auc: 0.9447 - val_loss: 0.2424 - learning_rate: 1.0000e-06
# Epoch 118/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.9447 - loss: 0.2424
# Epoch 118: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - auc: 0.9448 - loss: 0.2420 - val_auc: 0.9447 - val_loss: 0.2423 - learning_rate: 1.0000e-06
# Epoch 119/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.9457 - loss: 0.2401
# Epoch 119: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - auc: 0.9448 - loss: 0.2419 - val_auc: 0.9442 - val_loss: 0.2433 - learning_rate: 1.0000e-06
# Epoch 120/200
# 342/344 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9446 - loss: 0.2425
# Epoch 120: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - auc: 0.9446 - loss: 0.2424 - val_auc: 0.9448 - val_loss: 0.2422 - learning_rate: 1.0000e-06
# Epoch 121/200
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9455 - loss: 0.2408
# Epoch 121: val_auc did not improve from 0.94482
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - auc: 0.9448 - loss: 0.2420 - val_auc: 0.9444 - val_loss: 0.2430 - learning_rate: 1.0000e-06
# Epoch 121: early stopping
# Restoring model weights from the end of the best epoch: 106.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 87
#      83     )
#      84
#      85     val_preds = model.predict(X_val_transformed, verbose=0).ravel()
#      86
# ---> 87     oof_preds[valid_idx] = val_preds
#      88
#      89     auc = roc_auc_score(y_val, val_preds)
#      90     aucs.append(auc)
#
# NameError: name 'oof_preds' is not defined

# %% [markdown]
# ## Feature Selection

# %%
perm_result = permutation_importance(
    estimator=model, 
    X=X_train, 
    y=y_train.PitNextLap, 
    n_jobs=-1, 
    scoring='roc_auc'
)

importance_df = pd.DataFrame({
    "feature": X_train.columns.tolist(),
    "importance_mean": perm_result.importances_mean,
    "importance_std": perm_result.importances_std
}).sort_values(by="importance_mean", ascending=False)

# %%
importance_df.query("importance_mean <= 0").feature.tolist()

# %%
features_to_drop = importance_df.query("importance_mean <= 0").feature.tolist()

# %% [markdown]
# ## Fine Tuning

# %%
def objective(trial, X, y):

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    aucs = []

    for fold, (train_idx, valid_idx) in enumerate(cv.split(X, y)):

        X_train_fold = X.iloc[train_idx, :]
        X_valid_fold = X.iloc[valid_idx, :]

        y_train_fold = y.iloc[train_idx, 0]
        y_valid_fold = y.iloc[valid_idx, 0]

        model = make_pipeline(
            column_transformer,
            PCA(n_components=trial.suggest_float("n_components", 0.70, 0.99)),
            KNeighborsClassifier(
                n_neighbors=trial.suggest_int("n_neighbors", 3, 10),
                weights=trial.suggest_categorical("weights", ["uniform", "distance"]),
                metric=trial.suggest_categorical("metric", ["euclidean", "manhattan", "minkowski"]),
                p=trial.suggest_int("p", 1, 2),
                leaf_size=trial.suggest_int("leaf_size", 10, 100),
                n_jobs=-1
            )
        )

        model.fit(
            X_train_fold,
            y_train_fold
        )

        proba = model.predict_proba(X_valid_fold)[:, 1]

        auc = roc_auc_score(y_valid_fold, proba)
        aucs.append(auc)

        trial.report(np.mean(aucs), step=fold)

        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return np.mean(aucs)

study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner(n_warmup_steps=2))
study.optimize(lambda trial: objective(trial, X_train, y_train), n_trials=30, n_jobs=-1, show_progress_bar=True)


print("\nBest trial:")
print("AUC:", study.best_trial.value)

print("\nBest params:")
print(study.best_trial.params)
# Out:
# [I 2026-05-11 12:44:31,404] A new study created in memory with name: no-name-db190817-6948-4a8e-87aa-c130fdcbba45
# Best trial: 6. Best value: 0.883905:   0%|                                                     | 0/30 [07:10<?, ?it/s]
# [I 2026-05-11 12:51:41,099] Trial 6 finished with value: 0.8839054211779841 and parameters: {'C': 0.0016358117361472825}. Best is trial 6 with value: 0.8839054211779841.
# Best trial: 0. Best value: 0.886305:   7%|██▊                                       | 2/30 [07:46<1:32:35, 198.41s/it]
# [I 2026-05-11 12:52:16,811] Trial 0 finished with value: 0.8863046675032328 and parameters: {'C': 0.0023789673048510043}. Best is trial 0 with value: 0.8863046675032328.
# Best trial: 0. Best value: 0.886305:   7%|██▊                                       | 2/30 [08:06<1:32:35, 198.41s/it]
# [I 2026-05-11 12:52:37,278] Trial 8 finished with value: 0.8866326566749926 and parameters: {'C': 0.0025283134171682348}. Best is trial 8 with value: 0.8866326566749926.
# Best trial: 13. Best value: 0.890147:  13%|█████▍                                   | 4/30 [17:23<2:05:56, 290.64s/it]
# [I 2026-05-11 13:01:54,574] Trial 13 finished with value: 0.8901466318329765 and parameters: {'C': 0.0062202430296131395}. Best is trial 13 with value: 0.8901466318329765.
# Best trial: 12. Best value: 0.890871:  17%|██████▊                                  | 5/30 [18:14<1:25:06, 204.25s/it]
# [I 2026-05-11 13:02:45,334] Trial 12 finished with value: 0.8908710065313633 and parameters: {'C': 0.008697505374264797}. Best is trial 12 with value: 0.8908710065313633.
# Best trial: 7. Best value: 0.893042:  17%|███████                                   | 5/30 [23:02<1:25:06, 204.25s/it]
# [I 2026-05-11 13:07:32,775] Trial 7 finished with value: 0.8930422348229327 and parameters: {'C': 0.13220740878755075}. Best is trial 7 with value: 0.8930422348229327.
# Best trial: 9. Best value: 0.893049:  23%|█████████▊                                | 7/30 [23:23<1:02:39, 163.44s/it]
# [I 2026-05-11 13:07:54,328] Trial 9 finished with value: 0.8930485267418984 and parameters: {'C': 0.11948053825708975}. Best is trial 9 with value: 0.8930485267418984.
# Best trial: 11. Best value: 0.893114:  27%|███████████▍                               | 8/30 [23:24<40:57, 111.69s/it]
# [I 2026-05-11 13:07:55,444] Trial 11 finished with value: 0.8931139420093478 and parameters: {'C': 0.1438475029912712}. Best is trial 11 with value: 0.8931139420093478.
# Best trial: 11. Best value: 0.893114:  27%|███████████▍                               | 8/30 [23:59<40:57, 111.69s/it]
# [I 2026-05-11 13:08:31,065] Trial 2 finished with value: 0.8931959750336859 and parameters: {'C': 0.14809184364317304}. Best is trial 2 with value: 0.8931959750336859.
# Best trial: 2. Best value: 0.893196:  30%|█████████████▌                               | 9/30 [24:58<30:49, 88.07s/it]
# [I 2026-05-11 13:09:29,582] Trial 10 finished with value: 0.8932462226740476 and parameters: {'C': 0.21063725495333627}. Best is trial 10 with value: 0.8932462226740476.
# Best trial: 3. Best value: 0.89331:  37%|████████████████▌                            | 11/30 [26:23<25:30, 80.57s/it]
# [I 2026-05-11 13:10:54,180] Trial 3 finished with value: 0.8933101230691353 and parameters: {'C': 0.3205475790157562}. Best is trial 3 with value: 0.8933101230691353.
# Best trial: 3. Best value: 0.89331:  37%|████████████████▌                            | 11/30 [27:49<25:30, 80.57s/it]
# [I 2026-05-11 13:12:20,616] Trial 16 pruned.
# Best trial: 3. Best value: 0.89331:  40%|██████████████████                           | 12/30 [27:51<24:41, 82.31s/it]
# [I 2026-05-11 13:12:22,651] Trial 4 finished with value: 0.8934709027890545 and parameters: {'C': 0.47853686621079067}. Best is trial 4 with value: 0.8934709027890545.
# Best trial: 5. Best value: 0.893565:  47%|████████████████████▌                       | 14/30 [29:51<20:28, 76.75s/it]
# [I 2026-05-11 13:14:23,000] Trial 5 finished with value: 0.893564623581419 and parameters: {'C': 0.6325444858693001}. Best is trial 5 with value: 0.893564623581419.
# Best trial: 5. Best value: 0.893565:  47%|████████████████████▌                       | 14/30 [30:25<20:28, 76.75s/it]
# [I 2026-05-11 13:14:56,194] Trial 15 finished with value: 0.8919804507134769 and parameters: {'C': 0.017347322971565025}. Best is trial 5 with value: 0.893564623581419.
# Best trial: 1. Best value: 0.89364:  53%|████████████████████████                     | 16/30 [32:59<21:13, 90.99s/it]
# [I 2026-05-11 13:17:30,307] Trial 1 finished with value: 0.8936401285242039 and parameters: {'C': 2.157929693953863}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  53%|████████████████████████                     | 16/30 [42:38<21:13, 90.99s/it]
# [I 2026-05-11 13:27:08,758] Trial 14 finished with value: 0.8936240479445254 and parameters: {'C': 7.517823559731071}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  60%|██████████████████████████▍                 | 18/30 [47:47<51:50, 259.17s/it]
# [I 2026-05-11 13:32:19,296] Trial 17 finished with value: 0.8930237550431119 and parameters: {'C': 0.14806968819164545}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  60%|██████████████████████████▍                 | 18/30 [56:03<51:50, 259.17s/it]
# [I 2026-05-11 13:40:33,786] Trial 19 finished with value: 0.8934393244076331 and parameters: {'C': 2.316920799765996}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  67%|█████████████████████████████▎              | 20/30 [56:32<39:57, 239.74s/it]
# [I 2026-05-11 13:41:03,343] Trial 22 finished with value: 0.8934434716484887 and parameters: {'C': 1.873285708175247}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  67%|█████████████████████████████▎              | 20/30 [57:38<39:57, 239.74s/it]
# [I 2026-05-11 13:42:09,517] Trial 18 finished with value: 0.8935073958514541 and parameters: {'C': 6.203056655121497}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  70%|██████████████████████████████▊             | 21/30 [58:37<28:09, 187.78s/it]
# [I 2026-05-11 13:43:08,194] Trial 23 finished with value: 0.8934739735110007 and parameters: {'C': 2.06192948169482}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  77%|█████████████████████████████████▋          | 23/30 [59:01<12:59, 111.43s/it]
# [I 2026-05-11 13:43:32,243] Trial 21 finished with value: 0.8935190643917155 and parameters: {'C': 3.673289408699041}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  80%|████████████████████████████████████         | 24/30 [59:11<08:05, 80.99s/it]
# [I 2026-05-11 13:43:42,455] Trial 20 finished with value: 0.893474117060347 and parameters: {'C': 1.8328225714160857}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  83%|███████████████████████████████████▊       | 25/30 [1:00:31<06:43, 80.64s/it]
# [I 2026-05-11 13:45:02,488] Trial 24 finished with value: 0.8935564908057216 and parameters: {'C': 2.1625871244982764}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  87%|█████████████████████████████████████▎     | 26/30 [1:00:58<04:18, 64.52s/it]
# [I 2026-05-11 13:45:29,384] Trial 25 finished with value: 0.8935502539102325 and parameters: {'C': 2.932527429822434}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  90%|██████████████████████████████████████▋    | 27/30 [1:01:00<02:17, 45.89s/it]
# [I 2026-05-11 13:45:31,857] Trial 26 finished with value: 0.893559594012239 and parameters: {'C': 2.9269544031553507}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  93%|████████████████████████████████████████▏  | 28/30 [1:01:25<01:19, 39.65s/it]
# [I 2026-05-11 13:45:56,869] Trial 27 finished with value: 0.8935791390466763 and parameters: {'C': 3.3668321564182957}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364:  97%|█████████████████████████████████████████▌ | 29/30 [1:04:12<01:17, 77.99s/it]
# [I 2026-05-11 13:48:44,387] Trial 28 finished with value: 0.8935380631601776 and parameters: {'C': 8.345209904579416}. Best is trial 1 with value: 0.8936401285242039.
# Best trial: 1. Best value: 0.89364: 100%|██████████████████████████████████████████| 30/30 [1:05:33<00:00, 131.13s/it]
# [I 2026-05-11 13:50:05,372] Trial 29 finished with value: 0.8935148391304348 and parameters: {'C': 7.775222795693056}. Best is trial 1 with value: 0.8936401285242039.
# Best trial:
# 0.8936401285242039
# {'C': 2.157929693953863}

# %%
model_tuned = make_pipeline(
    column_transformer,
    LogisticRegression(
        **study.best_params,
        class_weight="balanced",
        max_iter=2000,
        random_state=42
    )
).fit(X_train, y_train.PitNextLap)

# %% [markdown]
# # Deploy

# %%
dump_pickle(model_tuned, '../models/model_logistic_regression.pkl')
