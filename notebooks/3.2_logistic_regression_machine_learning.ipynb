# %% [markdown]
# # Imports

# %%
import re
import optuna
import pickle

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.inspection import permutation_importance
from sklearn.model_selection import cross_val_score, StratifiedKFold

from feature_engine.selection import DropFeatures

# %% [markdown]
# ## Utils

# %%
def dump_pickle(file_obj, file_path):
    with open(file_path, 'bw') as file:
        pickle.dump(file_obj, file)

# %% [markdown]
# # Loading Dataset

# %%
X_train = pd.read_parquet('../data/X_train.parquet')
X_test = pd.read_parquet('../data/X_test.parquet')

y_train = pd.read_parquet('../data/y_train.parquet')

# %%
X_train.head()
# Out:
#     ordinal_encoder__compound  target_encoder__driver  \
# id
# 0                        0.50                0.203815
# 1                        0.50                0.199575
# 2                        0.50                0.218840
# 3                        0.25                0.200526
# 4                        0.50                0.192082
#
#     target_encoder__compound  target_encoder__race  \
# id
# 0                   0.328482              0.154734
# 1                   0.327181              0.176114
# 2                   0.326837              0.187526
# 3                   0.100888              0.145166
# 4                   0.327657              0.214557
#
#     standard_scaler__lapnumber  standard_scaler__position  \
# id
# 0                     1.585901                  -0.308849
# 1                     0.229628                  -1.066602
# 2                     2.116616                   0.638343
# 3                    -1.244581                  -0.498287
# 4                     0.170660                  -1.445478
#
#     standard_scaler__raceprogress  standard_scaler__year  \
# id
# 0                        1.487008              -1.486487
# 1                        0.033534               1.440545
# 2                        1.902200              -1.486487
# 3                       -1.029455              -0.510810
# 4                        0.092589              -1.486487
#
#     robust_scaler__position_change  robust_scaler__cumulative_degradation  \
# id
# 0                         1.666667                               1.040769
# 1                        -1.000000                              -5.009333
# 2                         1.000000                              -1.970285
# 3                         0.000000                               0.338641
# 4                         1.000000                               0.169816
#
#     ...  remainder__fuzzy_1_position_position_change  \
# id  ...
# 0   ...                                     0.947453
# 1   ...                                     0.074107
# 2   ...                                     0.226475
# 3   ...                                     0.088099
# 4   ...                                     0.256086
#
#     remainder__fuzzy_2_position_position_change  \
# id
# 0                                      0.005655
# 1                                      0.081854
# 2                                      0.059038
# 3                                      0.041344
# 4                                      0.040890
#
#     remainder__fuzzy_3_position_position_change  \
# id
# 0                                      0.020178
# 1                                      0.098684
# 2                                      0.614716
# 3                                      0.113803
# 4                                      0.083385
#
#     remainder__fuzzy_0_raceprogress_lapnumber  \
# id
# 0                                    0.000549
# 1                                    0.015175
# 2                                    0.024077
# 3                                    0.950726
# 4                                    0.009589
#
#     remainder__fuzzy_1_raceprogress_lapnumber  \
# id
# 0                                    0.997580
# 1                                    0.007697
# 2                                    0.912645
# 3                                    0.010153
# 4                                    0.004844
#
#     remainder__fuzzy_2_raceprogress_lapnumber  remainder__lap_time_inv  \
# id
# 0                                    0.001872                 0.012740
# 1                                    0.977128                 0.013316
# 2                                    0.063278                 0.014095
# 3                                    0.039121                 0.010598
# 4                                    0.985566                 0.009270
#
#     remainder__position_norm  remainder__is_pit_lap  \
# id
# 0                       0.40                      0
# 1                       0.20                      1
# 2                       0.65                      0
# 3                       0.35                      0
# 4                       0.10                      1
#
#     remainder__race_progress_sin
# id
# 0                       0.781831
# 1                       0.885456
# 2                       0.537300
# 3                       0.239316
# 4                       0.906308
#
# [5 rows x 60 columns]

# %%
X_test.head()
# Out:
#         ordinal_encoder__compound  target_encoder__driver  \
# id
# 439140                       0.25                0.182308
# 439141                       0.25                0.356316
# 439142                       0.25                0.121796
# 439143                       0.00                0.198847
# 439144                       0.50                0.197127
#
#         target_encoder__compound  target_encoder__race  \
# id
# 439140                  0.101132              0.133462
# 439141                  0.101132              0.150547
# 439142                  0.101132              0.133462
# 439143                  0.193475              0.253713
# 439144                  0.327536              0.114051
#
#         standard_scaler__lapnumber  standard_scaler__position  \
# id
# 439140                   -0.124182                  -1.066602
# 439141                    0.052723                  -1.634917
# 439142                    0.052723                   0.259466
# 439143                   -1.008708                   1.017219
# 439144                    1.703838                   0.448905
#
#         standard_scaler__raceprogress  standard_scaler__year  \
# id
# 439140                       0.261317              -0.510810
# 439141                       0.300590              -0.510810
# 439142                       0.489100              -0.510810
# 439143                      -1.025511               0.464868
# 439144                       1.518343               0.464868
#
#         robust_scaler__position_change  robust_scaler__cumulative_degradation  \
# id
# 439140                        0.000000                               0.396609
# 439141                        0.000000                               0.470778
# 439142                        0.000000                               0.301036
# 439143                        0.333333                               0.724449
# 439144                        2.333333                               0.003617
#
#         ...  remainder__fuzzy_1_position_position_change  \
# id      ...
# 439140  ...                                     0.001144
# 439141  ...                                     0.081596
# 439142  ...                                     0.087683
# 439143  ...                                     0.023113
# 439144  ...                                     0.718809
#
#         remainder__fuzzy_2_position_position_change  \
# id
# 439140                                     0.000465
# 439141                                     0.033933
# 439142                                     0.072629
# 439143                                     0.022859
# 439144                                     0.040632
#
#         remainder__fuzzy_3_position_position_change  \
# id
# 439140                                     0.000894
# 439141                                     0.053686
# 439142                                     0.701444
# 439143                                     0.935769
# 439144                                     0.151701
#
#         remainder__fuzzy_0_raceprogress_lapnumber  \
# id
# 439140                                   0.067702
# 439141                                   0.019477
# 439142                                   0.038897
# 439143                                   0.984826
# 439144                                   0.002043
#
#         remainder__fuzzy_1_raceprogress_lapnumber  \
# id
# 439140                                   0.028176
# 439141                                   0.011500
# 439142                                   0.031448
# 439143                                   0.002887
# 439144                                   0.991340
#
#         remainder__fuzzy_2_raceprogress_lapnumber  remainder__lap_time_inv  \
# id
# 439140                                   0.904122                 0.010708
# 439141                                   0.969023                 0.011005
# 439142                                   0.929655                 0.010768
# 439143                                   0.012287                 0.010530
# 439144                                   0.006618                 0.010090
#
#         remainder__position_norm  remainder__is_pit_lap  \
# id
# 439140                      0.20                      0
# 439141                      0.05                      0
# 439142                      0.55                      0
# 439143                      0.75                      0
# 439144                      0.60                      0
#
#         remainder__race_progress_sin
# id
# 439140                      0.954721
# 439141                      0.963550
# 439142                      0.992709
# 439143                      0.242362
# 439144                      0.766044
#
# [5 rows x 60 columns]

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Base

# %%
cv_results = cross_val_score(
    estimator=LogisticRegression(solver="lbfgs", max_iter=1000, class_weight="balanced"), 
    X=X_train, 
    y=y_train.PitNextLap, 
    scoring='roc_auc', 
    cv=StratifiedKFold(random_state=42, shuffle=True), 
    n_jobs=-1
)

# %%
cv_results.mean()
# Out:
# np.float64(0.8938920747817818)

# %%
model = LogisticRegression(solver="lbfgs", max_iter=1000, class_weight="balanced").fit(X_train, y_train.PitNextLap)

# %% [markdown]
# ## Feature Selection

# %%
perm_result = permutation_importance(
    estimator=model, 
    X=X_train, 
    y=y_train.PitNextLap, 
    n_jobs=-1, 
    scoring='roc_auc'
)


importance_df = pd.DataFrame({
    "feature": X_train.columns.tolist(),
    "importance_mean": perm_result.importances_mean,
    "importance_std": perm_result.importances_std
}).sort_values(by="importance_mean", ascending=False)

# %%
importance_df
# Out:
#                                               feature  importance_mean  \
# 4                          standard_scaler__lapnumber     3.798502e-01
# 23                           remainder__lapnumber_low     3.076602e-01
# 26                               remainder__stint_low     2.744066e-01
# 6                       standard_scaler__raceprogress     2.005298e-01
# 35                        remainder__raceprogress_low     1.096042e-01
# 37                       remainder__raceprogress_high     5.898939e-02
# 12                               robust_scaler__stint     4.421127e-02
# 5                           standard_scaler__position     3.663598e-02
# 24                        remainder__lapnumber_medium     3.478793e-02
# 36                     remainder__raceprogress_medium     3.296672e-02
# 18                     robust_scaler__tyre_life_ratio     2.776227e-02
# 29                            remainder__position_low     2.215591e-02
# 25                          remainder__lapnumber_high     1.467577e-02
# 2                            target_encoder__compound     9.485007e-03
# 31                           remainder__position_high     9.323062e-03
# 3                                target_encoder__race     9.084645e-03
# 28                              remainder__stint_high     7.935079e-03
# 14                            robust_scaler__tyrelife     6.765861e-03
# 49        remainder__fuzzy_0_position_position_change     5.387569e-03
# 32                           remainder__laptime_s_low     4.605873e-03
# 11                           robust_scaler__laptime_s     4.361436e-03
# 47  remainder__fuzzy_3_tyrelife_cumulative_degrada...     3.706951e-03
# 0                           ordinal_encoder__compound     3.598753e-03
# 52        remainder__fuzzy_3_position_position_change     3.142405e-03
# 34                          remainder__laptime_s_high     2.318252e-03
# 1                              target_encoder__driver     2.159452e-03
# 39         remainder__fuzzy_1_laptime_s_laptime_delta     2.015166e-03
# 43         remainder__fuzzy_5_laptime_s_laptime_delta     1.871442e-03
# 59                       remainder__race_progress_sin     1.626606e-03
# 50        remainder__fuzzy_1_position_position_change     1.597129e-03
# 30                         remainder__position_medium     1.460906e-03
# 17                      robust_scaler__stint_progress     1.382449e-03
# 55          remainder__fuzzy_2_raceprogress_lapnumber     1.368353e-03
# 57                           remainder__position_norm     1.299310e-03
# 45  remainder__fuzzy_1_tyrelife_cumulative_degrada...     1.070370e-03
# 48  remainder__fuzzy_4_tyrelife_cumulative_degrada...     7.630958e-04
# 41         remainder__fuzzy_3_laptime_s_laptime_delta     6.782069e-04
# 42         remainder__fuzzy_4_laptime_s_laptime_delta     5.319065e-04
# 15                   robust_scaler__delta_x_tyre_life     4.198601e-04
# 22                                 remainder__pitstop     3.641867e-04
# 58                              remainder__is_pit_lap     3.641867e-04
# 21                      robust_scaler__laps_since_pit     3.584915e-04
# 33                        remainder__laptime_s_medium     3.208167e-04
# 27                            remainder__stint_medium     3.176651e-04
# 51        remainder__fuzzy_2_position_position_change     3.138193e-04
# 38         remainder__fuzzy_0_laptime_s_laptime_delta     3.020911e-04
# 44  remainder__fuzzy_0_tyrelife_cumulative_degrada...     2.099460e-04
# 7                               standard_scaler__year     1.839392e-04
# 20                 robust_scaler__position_change_cum     1.835868e-04
# 54          remainder__fuzzy_1_raceprogress_lapnumber     1.762855e-04
# 16                  robust_scaler__compound_tyre_life     1.663962e-04
# 53          remainder__fuzzy_0_raceprogress_lapnumber     8.340355e-05
# 40         remainder__fuzzy_2_laptime_s_laptime_delta     6.151958e-05
# 19                 robust_scaler__degradation_per_lap     5.627760e-05
# 9               robust_scaler__cumulative_degradation     3.539215e-05
# 13                     robust_scaler__driver_mean_lap     9.213980e-06
# 10                       robust_scaler__laptime_delta     1.979793e-06
# 56                            remainder__lap_time_inv    -4.841063e-09
# 46  remainder__fuzzy_2_tyrelife_cumulative_degrada...    -8.549941e-08
# 8                      robust_scaler__position_change    -2.949665e-07
#
#     importance_std
# 4     4.847663e-04
# 23    3.521407e-04
# 26    4.609609e-04
# 6     4.066858e-04
# 35    3.658697e-04
# 37    4.218934e-04
# 12    1.800897e-04
# 5     2.795978e-04
# 24    2.222247e-04
# 36    2.077610e-04
# 18    1.310662e-04
# 29    2.118538e-04
# 25    2.309844e-04
# 2     1.760380e-04
# 31    9.554452e-05
# 3     4.840054e-05
# 28    6.864223e-05
# 14    1.815882e-04
# 49    6.260118e-05
# 32    5.483260e-05
# 11    3.389930e-05
# 47    1.309086e-04
# 0     9.705954e-05
# 52    3.463536e-05
# 34    3.236411e-05
# 1     3.446013e-05
# 39    4.156208e-05
# 43    5.523794e-05
# 59    4.103278e-05
# 50    1.850892e-05
# 30    5.076298e-05
# 17    3.190535e-05
# 55    2.513081e-05
# 57    3.668062e-05
# 45    5.807380e-05
# 48    3.207120e-05
# 41    4.773614e-05
# 42    2.957192e-05
# 15    2.467428e-05
# 22    2.420202e-05
# 58    2.420202e-05
# 21    2.629783e-05
# 33    2.054457e-05
# 27    1.920903e-05
# 51    1.168193e-05
# 38    1.578485e-05
# 44    2.648631e-05
# 7     1.506455e-05
# 20    1.278959e-05
# 54    1.934536e-05
# 16    1.907682e-05
# 53    2.507370e-05
# 40    1.531510e-05
# 19    4.128158e-06
# 9     6.612853e-06
# 13    2.312650e-06
# 10    4.329337e-07
# 56    1.199969e-08
# 46    1.174628e-06
# 8     4.745302e-07

# %%
importance_df.query("importance_mean <= 0").feature.tolist()
# Out:
# ['remainder__lap_time_inv',
#  'remainder__fuzzy_2_tyrelife_cumulative_degradation',
#  'robust_scaler__position_change']

# %%
drop_feat = DropFeatures(features_to_drop=importance_df.query("importance_mean <= 0").feature.tolist())

# %% [markdown]
# ## Fine Tuning

# %%
def objective(trial, X, y):

    lg = LogisticRegression(
        C=trial.suggest_float("C", 1e-3, 10, log=True),
        class_weight="balanced",
        max_iter=2000,
        random_state=42
    )
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    aucs = []

    for fold, (train_idx, valid_idx) in enumerate(cv.split(X, y)):
        X_train, X_valid = X.iloc[train_idx, :], X.iloc[valid_idx, :]
        y_train, y_valid = y.iloc[train_idx, 0], y.iloc[valid_idx, 0]

        model = Pipeline([('drop_feat', drop_feat), ('lg', lg)])
        model.fit(X_train, y_train)
        proba = model.predict_proba(X_valid)[:, 1]

        auc = roc_auc_score(y_valid, proba)
        aucs.append(auc)

        trial.report(np.mean(aucs), step=fold)

        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return np.mean(aucs)

study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner(n_warmup_steps=2))
study.optimize(lambda trial: objective(trial, X_train, y_train), n_trials=50, n_jobs=-1, show_progress_bar=True)


print("Best trial:")
print(study.best_trial.value)
print(study.best_trial.params)
# Out:
# [I 2026-05-05 15:32:57,408] A new study created in memory with name: no-name-52e0ccb6-14fc-4ba6-a746-9f63e5ee3a0a
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-05-05 15:36:51,394] Trial 1 finished with value: 0.8793428950290776 and parameters: {'C': 0.0010113331110738063}. Best is trial 1 with value: 0.8793428950290776.
# [I 2026-05-05 15:37:05,035] Trial 4 finished with value: 0.8885882702715853 and parameters: {'C': 0.003723224170935332}. Best is trial 4 with value: 0.8885882702715853.
# [I 2026-05-05 15:37:49,344] Trial 10 finished with value: 0.8905218122766584 and parameters: {'C': 0.0062940379783962795}. Best is trial 10 with value: 0.8905218122766584.
# [I 2026-05-05 15:38:07,982] Trial 2 finished with value: 0.8906276909837963 and parameters: {'C': 0.006528239990707225}. Best is trial 2 with value: 0.8906276909837963.
# [I 2026-05-05 15:39:23,593] Trial 11 finished with value: 0.8923400428861322 and parameters: {'C': 0.016889987933130544}. Best is trial 11 with value: 0.8923400428861322.
# [I 2026-05-05 15:39:40,264] Trial 13 pruned.
# [I 2026-05-05 15:39:49,066] Trial 9 finished with value: 0.8925948376960667 and parameters: {'C': 0.02240656807562103}. Best is trial 9 with value: 0.8925948376960667.
# [I 2026-05-05 15:39:55,688] Trial 5 finished with value: 0.892523042104634 and parameters: {'C': 0.020720778771839875}. Best is trial 9 with value: 0.8925948376960667.
# [I 2026-05-05 15:42:21,281] Trial 6 finished with value: 0.8932115313817215 and parameters: {'C': 0.05954567074459535}. Best is trial 6 with value: 0.8932115313817215.
# [I 2026-05-05 15:46:28,318] Trial 15 finished with value: 0.8930724808594404 and parameters: {'C': 0.04604161857986947}. Best is trial 6 with value: 0.8932115313817215.
# [I 2026-05-05 15:46:43,724] Trial 8 finished with value: 0.8936746172232214 and parameters: {'C': 0.21853327449002877}. Best is trial 8 with value: 0.8936746172232214.
# [I 2026-05-05 15:47:35,363] Trial 3 finished with value: 0.893845189222026 and parameters: {'C': 0.5105222718367542}. Best is trial 3 with value: 0.893845189222026.
# [I 2026-05-05 15:48:49,497] Trial 7 finished with value: 0.893925467908257 and parameters: {'C': 1.779765138044358}. Best is trial 7 with value: 0.893925467908257.
# [I 2026-05-05 15:49:40,099] Trial 0 finished with value: 0.8939451640265859 and parameters: {'C': 2.217491467299308}. Best is trial 0 with value: 0.8939451640265859.
# [I 2026-05-05 15:51:38,590] Trial 12 finished with value: 0.8939508670548534 and parameters: {'C': 3.114352552435118}. Best is trial 12 with value: 0.8939508670548534.
# [I 2026-05-05 15:53:07,456] Trial 14 finished with value: 0.8939168643870508 and parameters: {'C': 2.101123957968513}. Best is trial 12 with value: 0.8939508670548534.
# [I 2026-05-05 15:55:13,374] Trial 19 finished with value: 0.8939641979790446 and parameters: {'C': 4.089734496390327}. Best is trial 19 with value: 0.8939641979790446.
# [I 2026-05-05 15:55:36,375] Trial 16 finished with value: 0.89397791083382 and parameters: {'C': 8.219742655772885}. Best is trial 16 with value: 0.89397791083382.
# [I 2026-05-05 15:55:48,842] Trial 18 finished with value: 0.8940055392422094 and parameters: {'C': 9.52244584088525}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 15:56:19,989] Trial 17 finished with value: 0.893982713149863 and parameters: {'C': 6.806545955022567}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 15:58:09,151] Trial 20 finished with value: 0.8939657512580894 and parameters: {'C': 9.81398389019019}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:01:10,115] Trial 21 finished with value: 0.8939062845200054 and parameters: {'C': 0.7706175051606852}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:01:45,633] Trial 22 finished with value: 0.8939072855439173 and parameters: {'C': 0.7979430753407197}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:03:18,875] Trial 23 finished with value: 0.8939301231852055 and parameters: {'C': 0.9908117978077586}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:04:22,953] Trial 24 finished with value: 0.893946996484452 and parameters: {'C': 3.093709842214723}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:05:19,303] Trial 25 finished with value: 0.8939657946322612 and parameters: {'C': 5.093688767474031}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:08:15,261] Trial 26 finished with value: 0.8939499190095983 and parameters: {'C': 9.867979082823844}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:09:19,774] Trial 27 finished with value: 0.8939845456414195 and parameters: {'C': 6.815539730555349}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:10:58,919] Trial 31 finished with value: 0.8938518541767155 and parameters: {'C': 0.5475107271207937}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:11:06,217] Trial 28 finished with value: 0.8939697507850332 and parameters: {'C': 7.5733937502824435}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:12:11,510] Trial 30 finished with value: 0.8939821385569766 and parameters: {'C': 9.751632308943389}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:12:11,789] Trial 29 finished with value: 0.8939646411511 and parameters: {'C': 6.538371196878576}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:13:58,632] Trial 32 finished with value: 0.893940229190225 and parameters: {'C': 9.974761530577736}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:17:44,866] Trial 34 finished with value: 0.8939947114960157 and parameters: {'C': 8.115330419001573}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:18:10,177] Trial 33 finished with value: 0.8939933151527797 and parameters: {'C': 8.965322199292055}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:19:38,548] Trial 35 finished with value: 0.8939538517724029 and parameters: {'C': 9.76791818036899}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:20:34,292] Trial 36 finished with value: 0.8939763780538061 and parameters: {'C': 8.980810132569681}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:20:47,292] Trial 38 finished with value: 0.8936358064191948 and parameters: {'C': 0.2019174678535359}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:21:21,415] Trial 37 finished with value: 0.8939783652673985 and parameters: {'C': 8.103130432308344}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:21:59,690] Trial 39 finished with value: 0.8936968139895862 and parameters: {'C': 0.2661240372178302}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:22:13,279] Trial 41 finished with value: 0.8935554432694788 and parameters: {'C': 0.14853674451001225}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:24:37,348] Trial 40 finished with value: 0.8937824738485128 and parameters: {'C': 0.31207175001507315}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:26:31,887] Trial 42 finished with value: 0.8939246015608472 and parameters: {'C': 1.3195802216794827}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:26:35,651] Trial 43 finished with value: 0.8939356231578126 and parameters: {'C': 1.5435838483218784}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:27:21,903] Trial 44 finished with value: 0.8939123412357797 and parameters: {'C': 1.6059545839511096}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:28:46,551] Trial 47 finished with value: 0.8937070437012681 and parameters: {'C': 0.2589492953144229}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:29:02,423] Trial 45 finished with value: 0.8939628475843294 and parameters: {'C': 1.5491648008023202}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:29:12,629] Trial 46 finished with value: 0.8939353754877818 and parameters: {'C': 1.6435246699185808}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:29:37,167] Trial 48 finished with value: 0.8939515732208602 and parameters: {'C': 1.3970800931152476}. Best is trial 18 with value: 0.8940055392422094.
# [I 2026-05-05 16:29:44,738] Trial 49 finished with value: 0.8939052737085038 and parameters: {'C': 1.3920677065695128}. Best is trial 18 with value: 0.8940055392422094.
# Best trial:
# 0.8940055392422094
# {'C': 9.52244584088525}

# %%
model_tuned = LogisticRegression(
    class_weight="balanced",
    max_iter=2000,
    random_state=42,
    **study.best_params
)

pipe_tuned = Pipeline([('drop_feat', drop_feat), ('xgb', model_tuned)])
pipe_tuned.fit(X_train, y_train.PitNextLap)
# Out:
# Pipeline(steps=[('drop_feat',
#                  DropFeatures(features_to_drop=['remainder__lap_time_inv',
#                                                 'remainder__fuzzy_2_tyrelife_cumulative_degradation',
#                                                 'robust_scaler__position_change'])),
#                 ('xgb',
#                  LogisticRegression(C=9.52244584088525, class_weight='balanced',
#                                     max_iter=2000, random_state=42))])

# %% [markdown]
# # Deploy

# %%
dump_pickle(pipe_tuned, '../models/model_logistic_regression.pkl')
